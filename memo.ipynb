# %% [markdown]
# # 这是一个大标题
# ## 这是一个标题
# ### 这是一个小标题
#
#         This is some code.

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.arange(12)
b = np.power(np.e, np.arange(12))
plt.plot(a, b)
